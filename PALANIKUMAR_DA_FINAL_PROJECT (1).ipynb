# %% [markdown]
# # Project Title : Amazon Sales 2025

# %% [markdown]
# # Domain : E - Commerce

# %% [markdown]
# # Objective
#
# *   To analyze e-commerce sales performance by evaluating order volumes, popular product categories, and most requested items.
#
# *   To understand customer insights by analyzing reviews, purchase history, and demographics to inform marketing strategies.
#
# *   To identify sales trends and seasonality to optimize inventory management and future demand forecasting.

# %% [markdown]
# # Outcome
#
# *   Overall Financial and Sales Metrics.
#
# *   Shifting Consumer Behavior and Marketing.
# *   Operational and Seller Success.

# %% [markdown]
# #Dataset Information:
#
# Source: https://www.kaggle.com/code/ibrahimqasimi/amazon-sales-2025-complete-eda-ml-models-95-acc
#
# Year / Timeline: Data collected during 2025
#
# ### Dataset Description:
#
# A dataset containing simulated or actual e-commerce transaction data from 2025 for projects like sales analysis, customer behavior study, or performance prediction. And Amazon products, pricing, discount patterns, ratings, reviews, and metadata. It includes more than 1,000 product listings, scraped from Amazon’s website using BeautifulSoup and WebDriver.

# %% [markdown]
# #Type of Analysis
#
# Descriptive Analysis (summarizing the dataset)
#
# Diagnostic Analysis (finding reasons behind patterns)
#
# Predictive Analysis (optional if forecasting required using basic stats)
#
# Prescriptive Analysis (recommendations for business decisions)

# %% [markdown]
# # Stages for DA Project

# %% [markdown]
# ## Stage 1 – Problem Definition and Dataset Selection
#
# # Define the business problem and expected outcome
#
# *   Amazon offers a vast range of products, but not all items perform equally well in terms of sales. The company needs a way to predict whether a product will be a high seller or not based on its features—such as category, price, rating, discount, and more.
# *   Predicts whether a product will be a high-performing seller.
# *   Achieves high accuracy (target: 95%) using models like XGBoost.
# *   Identifies the most influential features driving sales.
# *   Provides actionable insights to support business decisions in:
#
#         * Inventory planning
#         * Promotional targeting
#         * Product listing optimization.
#
# # Choose dataset and explain its source, size, and features
# # Dataset Sourse
# *   Name : Amazon Sales 2025
# *   Sourse : https://www.kaggle.com/code/ibrahimqasimi/amazon-sales-2025-complete-eda-ml-models-95-acc/input
#
# *   Format : CSV File
# *   Shape of the Dataset: 1465 rows and 16 columns.
#
# # Dataset Feature:
#
# *   product_id : Unique identifier for each product.
# *   product_name : Name of the product.
# *   category : Product category.
# *   discounted_price : Final discounted price.
# *   actual_price : Original listed price
# *   discount_percentage : Discount applied in percentage.
# *   rating : Average customer rating
# *   rating_count : Number of customers who rated.
# *   about_product : Short description
# *   user_id, user_name : Reviewer details
# *   review_id, review_title, review_content : Review details
#
# Import libraries, load dataset
#
# Dataset description (rows, columns, features)
#
# Initial EDA (head, info, describe, shape, null checks, duplicate check)

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53f0762c-f185-4de1-bcfa-365e941612c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53f0762c-f185-4de1-bcfa-365e941612c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Display first few rows
df = pd.read_csv('amazon.csv.zip')
display(df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
# check column names
print("Column Names:", df.columns.tolist())

# check detailed info
df.info()
# Out:
# Column Names: ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
# ...

# %%
### Initial EDA (head, info, describe, shape, null checks, duplicate check)

df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Stage 2 – Data Cleaning and Pre-processing
#
# Handle missing values (impute or drop)
#
# Handle duplicates
#
# Treat outliers if required
#
# Check skewness and apply transformations
#
# Convert data types if needed
#
# Feature transformations (date parts, derived fields if required for analysis)

# %% [markdown]
# ## Result (Handling Missing Values):
# **No Missing values found in the DataSet.**
#
# since marks allocated for handling missing values codes are written below:

# %%
# Handle missing values (impute or drop)

# filling categorical with mode, numerical with median (or drop if few)
for col in df.columns:
    if df[col].dtype == 'object':
        df[col].fillna(df[col].mode()[0],inplace = True)
    else:
        df[col].fillna(df[col].median(),inplace = True)

# Verifying again
df.isnull().sum()
# Out:
# /tmp/ipython-input-1863259375.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0],inplace = True)
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# ...

# %%
# Handle duplicates

# Check duplicates
df.duplicated().sum()

# Drop duplicates
df.drop_duplicates(inplace=True)

# Verifying again
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Result (Handling Duplicates):
# **No Duplicates found in the DataSet.**
#
# since marks allocated for handling Duplicates, codes are written below:

# %%
# Treat outliers using IQR (remove extreme values)

def treat_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    # keep only values inside the limits
    df = df[(df[column] >= lower_limit) & (df[column] <= upper_limit)]
    return df

# %% [markdown]
# ## Result (Handling Outliers):
# **No outliers found for the numerical columns in the Dataset.**

# %%
# Check skewness and apply transformations

# Define numerical columns before checking skewness
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Check skewness
df[num_cols].skew()
# Out:
# Series([], dtype: float64)

# %%
def log_transform(col):
    return np.log1p(df[col])

def sqrt_transform(col):
    return np.sqrt(df[col])

print("\nData is approximately normally distributed → No transformations required.")
# Out:
# Data is approximately normally distributed → No transformations required.

# %% [markdown]
# ## Result(checking Skewness):
# **All numeric columns have skewness values between -0.01 and +0.02,
# The data is approximately normally distributed.**
#
# No transformations (like log or sqrt) are required for these variables.
#
# Since marks are allocated, codes written below:

# %%
# Convert price to float

df['discounted_price'] = (
    df['discounted_price'].astype(str).str.replace("₹", "").str.replace(",", "").astype(float)
)
df['actual_price'] = (
    df['actual_price'].astype(str).str.replace("₹", "").str.replace(",", "").astype(float)
)

# Convert discount percentage to fraction
df['discount_percentage'] = (
    df['discount_percentage'].astype(str).str.replace("%", "").astype(float) / 100
)

# Clean & convert ratings
df['rating'] = df['rating'].astype(str).replace("|", "3.9").astype(float)

# Convert rating_count to numeric
df['rating_count'] = df['rating_count'].astype(str).str.replace(",", "").astype(float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
#checking the Changes
display(df.iloc[1080:1102])
# Out:
#       product_id                                       product_name  \
# 1080  B0BPBXNQQT  Room Heater Warmer Wall-Outlet 400 Watts Elect...
# 1081  B00W56GLOQ  Wonderchef Nutri-blend Mixer, Grinder & Blende...
# 1082  B0883KDSXC  USHA Armor AR1100WB 1100 W Dry Iron with Black...
# 1083  B078V8R9BS  Butterfly EKN 1.5-Litre Electric Kettle (Silve...
# 1084  B08GSQXLJ2  Crompton Arno Neo 15-L 5 Star Rated Storage Wa...
# 1085  B01M5B0TPW  Borosil Chef Delite BCH20DBB21 300-Watt Choppe...
# 1086  B082KVTRW8  KENT 16055 Amaze Cool Touch Electric Kettle 1....
# 1087  B08CFJBZRK          Prestige IRIS Plus 750 watt mixer grinder
# 1088  B07H3WDC4X  Simxen Egg Boiler Electric Automatic Off 7 Egg...
# 1089  B09ZTZ9N3Q  Amazon Basics 2000/1000 Watt Room Heater with ...
# 1090  B083P71WKK  HealthSense Weight Machine for Kitchen, Kitche...
# 1091  B097R4D42G  Bajaj New Shakti Neo 10L Vertical Storage Wate...
# 1092  B07MKMFKPG   Bosch Pro 1000W Mixer Grinder MGM8842MIN - Black
# ...

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count           float64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %% [markdown]
# ## Result (Convert DataTypes):
# Converted categorical fields with ensured their datatypes are in appropriate format.

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635             0.476915     4.096451
# std         6944.304394   10874.826864             0.216359     0.291620
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000             0.320000     4.000000
# 50%          799.000000    1650.000000             0.500000     4.100000
# 75%         1999.000000    4295.000000             0.630000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#         rating_count
# count    1465.000000
# mean    18283.367235
# std     42725.921124
# min         2.000000
# 25%      1191.000000
# 50%      5179.000000
# 75%     17325.000000
# max    426973.000000

# %%
print("Final dataset shape:", df.shape)
df.info()
# Out:
# Final dataset shape: (1465, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
# ...

# %% [markdown]
# ## Stage 3 – EDA and Visualizations
#
# Univariate Analysis → distribution of single variables (countplot, histogram, boxplot)
#
# Bivariate Analysis → relation between two variables (scatterplot, barplot, correlation heatmap)
#
# Multivariate Analysis → relation among 3+ variables (pairplot, grouped analysis, pivot tables, advanced plots)
#
# Interpretation MUST with every visualization
#
# Focus on business story not just charts
#
# Each chart must be in seperate cells.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Univariate Analysis

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

sns.histplot(df['discounted_price'], kde=True, ax=axes[0,0], color="#FF4500")
axes[0,0].set_title("Distribution of Discounted Price")

sns.histplot(df['actual_price'], kde=True, ax=axes[0,1], color="orange")
axes[0,1].set_title("Distribution of Actual Price")

sns.histplot(df['discount_percentage'], kde=True, ax=axes[1,0], color=(0.2, 0.4, 0.8) )
axes[1,0].set_title("Distribution of Discount Percentage")

sns.histplot(df['rating'], kde=True, ax=axes[1,1], color="#FF5733")
axes[1,1].set_title("Distribution of Ratings")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretation of your above chart
#
# **Explain the Chart:**
#
# This figure consists of four histograms, each showing the distribution of a different numerical feature from the dataset. The purpose of these charts is to understand how values in each feature are spread across the dataset.
#
# 1. Distribution of Discounted Price:
#
# *   Indicates Amazon sells mostly budget and mid-range items.
# *   Whether most discounted prices are low, medium, or high.
# *   Whether the prices are balanced or skewed.
# 2. Distribution of Actual Price:
#
# *   Whether the catalog has mostly low-cost, mid-range, or premium products.
# *   It's very high-priced outliers.
# 3. Distribution of Discount Percentage:
#
#
# *   Common discount percentage (0.2% to 0.7%)
# *   Its aggressive Amazon’s discount.
# 4. Distribution of Ratings:
#
#
# *   If customers tend to give 4+ stars or if ratings are more mixed.
# *   The ratings are generally high.
#
# What is it saying?
#
# It explains how the prices are set, how much discount products usually get, and how satisfied customers are based on their ratings.
#
# What features you used?
#
# *   Discount_price
# *   Actual_price
# *   Discount_percentage
# *   Ratings
#
# From this what you are showing us?
#
#
# *   Each numerical variable shows a specific distribution pattern.
# The histograms reveal whether the values are symmetrically distributed, skewed, or clustered in particular ranges.
# *   The ranges of Low, Medium and High Values.
# *   Prices are clustered around specific values
# *   Moderate (20–50%)
# *   if there are many low ratings (<3) Most Amazon datasets show ratings skewed toward positive values.
# *   Abnormally large discounts

# %%
unique_ratings_count = df['rating'].nunique()
palette = sns.color_palette('viridis', n_colors=unique_ratings_count, as_cmap=False)
plt.figure(figsize=(10,6))
sns.countplot(y='rating', data=df, order=df['rating'].value_counts().index, palette=palette, hue='rating', legend=False)
plt.title("Count of Products by Rating")
plt.show()

# %% [markdown]
# *   The countplot shows how many products have each rating value.Most ratings fall in the higher range, meaning many products receive good customer feedback.
# *   Ratings with longer bars are the most common, showing that customers generally give high ratings, while lower ratings appear less frequently. This indicates overall strong customer satisfaction across the products.

# %% [markdown]
# #Bivariate Analysis

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="actual_price", y="rating", data=df, alpha=0.6, color="#FF5733")
plt.title("Actual Price vs Rating")
plt.show()

# %% [markdown]
# *   The scatter plot shows the relationship between the actual price of products and their customer ratings.
# *   From the chart, we can see that ratings remain fairly consistent across different price levels. Both low-priced and high-priced products receive similar ratings.

# %% [markdown]
# # Advanced Visualization

# %%
plt.figure(figsize=(8,6))
corr = df[['discounted_price','actual_price','discount_percentage','rating','rating_count']].corr()
sns.heatmap(corr, annot=True, cmap=palette, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# **What this chart shows:**
#
# This heatmap displays how strongly different numerical features are related to one another.
#
# **Chart type:**
#
# Correlation Heatmap
#
# **Libraries used:**
#
#
# *   seaborn
# *   Lmatplotlib
#
# **What it is saying:**
#
#
# *   Actual_price and discounted_price show strong positive correlation — higher actual prices usually have higher discounted prices.
# *   Discount_percentage tends to be negatively correlated with price — bigger discounts often apply to higher-priced products.
#
# *   Rating and rating_count may show weak or moderate correlation — popular products don’t always have higher ratings.
#
# *   Overall, the heatmap highlights which features move together and which do not.

# %% [markdown]
# #Multivariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select the numeric columns you want in the pairplot
pairplot_columns = ['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']

# Create the pairplot
sns.pairplot(df[pairplot_columns], diag_kind="kde", corner=True)

plt.suptitle("Pairplot of Amazon Product Features", y=1.02)
plt.show()

# %% [markdown]
# #Interpretation:
#
#
# *   The pairplot shows clear positive relationships between the price features, meaning higher actual prices usually lead to higher discounted prices.
# *   Other variables like rating and discount percentage show weak relationships, indicating they do not strongly depend on product price.

# %%
plt.figure(figsize=(10,5))
ax=sns.histplot(df['discounted_price'], bins=5, kde=True,color ='orange',edgecolor = "brown")
plt.title('Distribution of Discounted Price',fontsize=14, weight='bold', color='purple')
plt.xlabel('Discounted Price (INR)',fontsize=12, weight='bold', color='green')
plt.ylabel('No.Of.Products',fontsize=12, weight='bold', color='green')
ax.bar_label(ax.containers[0])
plt.grid(True,alpha = 0.3)
plt.show()

# %% [markdown]
# #Interpretation:
# The distribution clearly shows that discounted prices (INR) are heavily concentrated in the lower range, indicating that budget-friendly products make up the majority of the catalog, with only a small number of high-priced items.

# %%
# Round ratings to nearest integer for grouping
df['rating_rounded'] = df['rating'].round()

rating_share = df['rating_rounded'].value_counts().sort_index()

# New custom color palette
colors = sns.color_palette("Spectral", n_colors=len(rating_share))

plt.figure(figsize=(8,8))
plt.pie(
    rating_share,
    labels=rating_share.index.astype(str) + " Stars",
    autopct="%1.1f%%",
    startangle=140,
    colors=colors,
    wedgeprops={'edgecolor': 'black'}
)
plt.title("Share of Products by Rating", fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# #Interpretation:
#
#
# *   Most products fall within the mid-rating range, indicating generally average customer satisfaction.
# *   Very high or very low ratings are less common, showing that extreme satisfaction or dissatisfaction is relatively rare.

# %% [markdown]
# ### Average Rating by Top 10 Product Categories

# %%
# Calculate average rating per category
category_ratings = df.groupby('category')['rating'].mean().sort_values(ascending=False)

# Select top 10 categories
top_10_categories = category_ratings.head(10)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_categories.index, y=top_10_categories.values, palette='viridis', hue=top_10_categories.index, legend=False)
plt.title('Average Rating of Top 10 Product Categories', fontsize=16)
plt.xlabel('Product Category', fontsize=12)
plt.ylabel('Average Rating', fontsize=12)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation:
# *   This bar chart displays the average customer rating for the top 10 product categories. Each bar represents a category, and its height indicates the average rating received by products within that category.
# *   This visualization helps identify which product categories consistently receive high customer satisfaction, potentially guiding inventory and marketing strategies.

# %% [markdown]
# ### Visualizing Average Discounted Price by Category (from Pivot Table)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the pivot table by discounted_price for better visualization
visual_data = pivot_table_category.sort_values(by='discounted_price', ascending=False).head(15) # Taking top 15 for clarity

plt.figure(figsize=(14, 8))
sns.barplot(
    x=visual_data.index,
    y=visual_data['discounted_price'],
    palette='magma',
    hue=visual_data.index,
    legend=False
)
plt.title('Top Categories by Average Discounted Price', fontsize=16)
plt.xlabel('Product Category', fontsize=12)
plt.ylabel('Average Discounted Price', fontsize=12)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation of Average Discounted Price by Category
#
# **Explain the Chart:**
# This bar chart visualizes the average discounted price for the top 15 product categories, derived from our pivot table. Categories are sorted in descending order by their average discounted price, allowing for easy identification of the most expensive and more affordable product groups after discounts.
#
# **What is it saying?**
# *   **Pricing Landscape:** The chart clearly shows which categories command higher average discounted prices, giving insight into the general pricing tier of products within those segments.
# *   **Value Perception:** While this chart doesn't directly show profitability or sales volume, understanding average discounted prices helps in strategizing promotions and understanding customer expectations for price points in different categories.
#
# **What features you used?**
# *   **X-axis:** `Category` (product category names from the pivot table index)
# *   **Y-axis:** `discounted_price` (average discounted price for each category)
#
# **From this what you are showing us?**
# This visualization highlights:
# *   The dominant categories in terms of average selling price after discounts.
# *   Potential areas for focused marketing strategies, either for premium segments or for high-volume, lower-priced segments.
# *   It helps in understanding the market positioning of various product categories based on their price points.

# %%
# Step 1: Install folium
# !pip install folium

# Step 2: Import libraries
import folium
import pandas as pd

# Step 3: Sample data with latitude and longitude
data = {
    'Store': ['Amazon NY', 'Amazon SF', 'Amazon TX'],
    'Latitude': [40.7128, 37.7749, 31.9686],
    'Longitude': [-74.0060, -122.4194, -99.9018]
}
df = pd.DataFrame(data)

# Step 4: Create a base map centered in the US
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Step 5: Add markers to the map
for _, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Store'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

# Step 6: Display the map in Colab
m
# Out:
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ## Interpretation of your above chart:
# #1. Strategic Geographic Coverage:
#
# The map shows that Amazon has strategically placed stores in key regions across the U.S.—New York (East Coast), San Francisco (West Coast), and Texas (South Central). This distribution suggests a deliberate effort to cover major population centers and logistical hubs.
#
# **Implication:**
#
# Amazon can ensure faster delivery times and better customer service coverage across diverse regions.
#
# #2. Regional Sales or Demand Focus:
# If these markers represent high-performing sales zones, the map highlights where Amazon’s customer demand is strongest. These cities may be driving a significant portion of revenue due to urban density, tech-savvy populations, or purchasing power.
#
# **Implication:**
#
# Marketing and inventory strategies can be tailored to reinforce performance in these regions or replicate success in similar cities.

# %% [markdown]
# ## Stage 4 – Documentation, Insights and Presentation
#
# Show a dashboard aligning all the charts in powerbi by connecting python in PowerBI
#
# Summarize findings in plain English (what do the patterns mean)
#
# Highlight 3–5 key insights (trends, anomalies, correlations)
#
# Provide recommendations for business or decision-making
#
# Explain the FINAL STORY WITH THE DASHBOARD
#
# Create a PDF pasting your DASHBOARD, explaining all the above mentioned concepts and submit it

# %%
# your stage 4 pdf Link

'''
step1 --> Create a docs that should have all the above mentioned
step2 --> Save it as "Stage4_doc"
Step3 --> Download it as PDF
step4 --> Upload the pdf in your drive
step5 --> Right click on your pdf in drive
step6 --> click share and change access into anyone with the link (Viewer)
step7 --> click copy link and paste it here...
You are done.
'''

# %% [markdown]
# # Future Enhancement
#
# Use a larger or more recent dataset for deeper insights
#
# Automate parts of the analysis with scripts or dashboards
#
# Add advanced visualizations and interactive dashboards in Power BI or Tableau
#
# Extend the analysis to predictive modeling for forecasting if needed

# %% [markdown]
# # Conclusion
#
# From the analysis, we identified meaningful relationships and patterns in the dataset. The visualizations and insights highlight the main factors influencing the outcomes and provide a strong foundation for business decisions.
